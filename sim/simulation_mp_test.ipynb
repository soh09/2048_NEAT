# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import time

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from Simulation_Multiprocessing import Simulation
import neural_net.nn as nn
from neural_net.visualize import visualize_genome, visualize_net, display_gene
from Sandbox import Sandbox
import random

# %%
a = Simulation()
# Out:
# 1000 NetworkGenomes created, ready for simulation

# %%
a.simulate()
a.adjust_fitness()
a.reproduce()
# [s.fitness for s in a.species[0]['children']]


for i in range(30):
    now = time.time()
    a.mutate_and_speciate()
    mas = time.time() - now

    now = time.time()
    a.simulate()
    sim = time.time() - now

    a.adjust_fitness()

    a.reproduce()

    print(f'mutate: {mas:.3f}, simulate: {sim:.3f}')
# Out:
# (max, avg) unadjusted fitness of generation 0 = (32, 5.748)
# number of species: 1
# (max, avg) unadjusted fitness of generation 1 = (32, 5.794)
# number of species: 16
# mutate: 0.042, simulate: 0.708
# (max, avg) unadjusted fitness of generation 2 = (64, 6.286)
# number of species: 24
# mutate: 0.276, simulate: 0.370
# (max, avg) unadjusted fitness of generation 3 = (32, 5.75)
# number of species: 28
# mutate: 0.120, simulate: 0.607
# (max, avg) unadjusted fitness of generation 4 = (32, 5.586)
# number of species: 39
# mutate: 0.191, simulate: 0.832
# (max, avg) unadjusted fitness of generation 5 = (32, 5.616)
# number of species: 53
# mutate: 0.353, simulate: 0.985
# (max, avg) unadjusted fitness of generation 6 = (32, 5.86)
# number of species: 65
# mutate: 0.882, simulate: 0.921
# (max, avg) unadjusted fitness of generation 7 = (32, 6.138)
# number of species: 70
# mutate: 0.487, simulate: 1.617
# (max, avg) unadjusted fitness of generation 8 = (64, 6.14)
# number of species: 80
# mutate: 0.546, simulate: 2.085
# (max, avg) unadjusted fitness of generation 9 = (32, 6.152)
# number of species: 92
# mutate: 0.712, simulate: 2.509
# (max, avg) unadjusted fitness of generation 10 = (32, 6.178)
# number of species: 102
# mutate: 0.742, simulate: 2.089
# (max, avg) unadjusted fitness of generation 11 = (32, 6.122)
# number of species: 106
# mutate: 0.636, simulate: 2.516
# (max, avg) unadjusted fitness of generation 12 = (64, 5.924)
# number of species: 115
# mutate: 0.919, simulate: 3.551
# (max, avg) unadjusted fitness of generation 13 = (32, 6.114)
# number of species: 127
# mutate: 2.505, simulate: 3.074
# (max, avg) unadjusted fitness of generation 14 = (64, 6.048)
# number of species: 136
# mutate: 1.266, simulate: 3.396
# (max, avg) unadjusted fitness of generation 15 = (64, 6.222)
# number of species: 142
# mutate: 1.044, simulate: 3.656
# (max, avg) unadjusted fitness of generation 16 = (64, 6.268)
# number of species: 153
# mutate: 3.277, simulate: 4.343
# (max, avg) unadjusted fitness of generation 17 = (64, 6.346)
# number of species: 163
# mutate: 1.730, simulate: 4.871
# (max, avg) unadjusted fitness of generation 18 = (64, 6.218)
# number of species: 176
# mutate: 3.556, simulate: 5.560
# (max, avg) unadjusted fitness of generation 19 = (64, 6.5)
# number of species: 187
# mutate: 2.136, simulate: 5.368
# (max, avg) unadjusted fitness of generation 20 = (64, 6.808)
# number of species: 194
# mutate: 1.623, simulate: 5.767
# (max, avg) unadjusted fitness of generation 21 = (32, 6.704)
# number of species: 203
# mutate: 2.027, simulate: 5.802
# (max, avg) unadjusted fitness of generation 22 = (32, 6.506)
# number of species: 211
# mutate: 4.607, simulate: 6.455
# (max, avg) unadjusted fitness of generation 23 = (64, 6.848)
# number of species: 221
# mutate: 1.980, simulate: 6.349
# (max, avg) unadjusted fitness of generation 24 = (64, 7.026)
# number of species: 230
# mutate: 4.852, simulate: 6.912
# (max, avg) unadjusted fitness of generation 25 = (32, 6.954)
# number of species: 237
# mutate: 1.975, simulate: 7.648
# (max, avg) unadjusted fitness of generation 26 = (32, 6.584)
# number of species: 247
# mutate: 2.347, simulate: 7.916
# (max, avg) unadjusted fitness of generation 27 = (64, 6.936)
# number of species: 261
# mutate: 6.419, simulate: 8.170
# (max, avg) unadjusted fitness of generation 28 = (64, 6.986)
# number of species: 269
# mutate: 2.651, simulate: 8.602
# (max, avg) unadjusted fitness of generation 29 = (64, 7.012)
# number of species: 282
# mutate: 7.023, simulate: 9.365
# (max, avg) unadjusted fitness of generation 30 = (64, 6.824)
# number of species: 295
# mutate: 3.105, simulate: 9.262

# %%
visualize_genome(a.species[115]['children'][1], 'LR', False, '2')
