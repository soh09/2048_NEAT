# %%
# %load_ext autoreload
# %autoreload 2

import sys
import gc
import os
import time
import psutil

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join('..')))
from diagnose_gc_issue import diagnose_generation

# Enable debugging with verbosity
gc.set_debug(gc.DEBUG_UNCOLLECTABLE)

# Initialize counters for each generation
deallocated_objects = {0: 0, 1: 0, 2: 0}

# # Callback function to tally deallocated objects
# def gc_callback(phase, info):
#     if phase == "stop":  # Only tally after GC has finished
#         gen = info['generation']
#         deallocated_objects[gen] += info['collected']

# # Attach the callback to GC events
# gc.callbacks.append(gc_callback)

# %%
from Simulation_Multiprocessing import Simulation
# Out:
# luts loaded successfully.

# %%
import neural_net.nn as nn
from neural_net.visualize import visualize_genome, visualize_net, display_gene
from Sandbox import Sandbox
import random

# %%
logging_path = 'C:\\Users\\hirot\Documents\\2048_NEAT\\logs\\actual_logs'
checkpoint_path = 'C:\\Users\\hirot\Documents\\2048_NEAT\\checkpoints'
a = Simulation(log_folder = logging_path, checkpoint_folder = checkpoint_path)
# Out:
# 1000 NetworkGenomes created, ready for simulation

# %%
a.deallocated_objects
# Out:
# {0: 0, 1: 0, 2: 0}

# %%
a.simulate()

a.adjust_fitness()

a.reproduce()

a.mutate_and_speciate()
# [s.fitness for s in a.species[0]['children']]


for i in range(10):

    now = time.time()
    a.simulate()
    sim = time.time() - now

    a.adjust_fitness()

    a.reproduce()

    now = time.time()
    a.mutate_and_speciate()
    mas = time.time() - now
    print(f'mutate: {mas:.3f}, simulate: {sim:.3f}')

    if i % 20 == 0:
        now = time.time()
        gc.collect()
        print(f'time to gc: {time.time() - now}')
        diagnose_generation(a.genomes, a.current_gen)

    print('--------------------------------')
# Out:
# new best genome exists
# new best genome exists
# 115 vs 73
# (max, avg) unadjusted fitness of generation 0 = (115, 10.074)
# total # of species: 1, # of stagnant species: 0
# [0]
# new best genome exists
# 117 vs 115
# (max, avg) unadjusted fitness of generation 1 = (117, 10.484)
# total # of species: 1, # of stagnant species: 0
# [0]
# mutate: 0.038, simulate: 0.376
# time to gc: 0.03500008583068848
#
# === Generation 2 Diagnosis ===
#
# Object counts:
#   NetworkGenome: 1001
#   NeuronGene: 20042
#   SynapseGene: 64132
#
# Neuron synapse stats:
#   Total neurons: 20002
#   Total synapse refs: 64004
#   Max synapses per neuron: 5
#   Neurons with excess synapses: 0
#
# GC stats:
#   Gen 0 objects: 13
#   Gen 1 objects: 0
#   Gen 2 objects: 321525
# --------------------------------
# new best genome exists
# 125 vs 117
# (max, avg) unadjusted fitness of generation 2 = (125, 9.738)
# total # of species: 1, # of stagnant species: 0
# [0]
# mutate: 0.040, simulate: 0.371
# --------------------------------
# new best genome exists
# 127 vs 125
# (max, avg) unadjusted fitness of generation 3 = (127, 11.026)
# total # of species: 1, # of stagnant species: 0
# [0]
# mutate: 0.038, simulate: 0.362
# --------------------------------
# (max, avg) unadjusted fitness of generation 4 = (117, 10.944)
# total # of species: 1, # of stagnant species: 0
# [0]
# mutate: 0.041, simulate: 0.386
# --------------------------------
# (max, avg) unadjusted fitness of generation 5 = (123, 11.698)
# total # of species: 1, # of stagnant species: 0
# [0]
# mutate: 0.038, simulate: 0.367
# --------------------------------
# new best genome exists
# 207 vs 127
# (max, avg) unadjusted fitness of generation 6 = (207, 10.424)
# total # of species: 1, # of stagnant species: 0
# [0]
# mutate: 0.040, simulate: 0.411
# --------------------------------
# (max, avg) unadjusted fitness of generation 7 = (179, 10.99)
# total # of species: 1, # of stagnant species: 0
# [0]
# mutate: 0.040, simulate: 0.381
# --------------------------------
# (max, avg) unadjusted fitness of generation 8 = (111, 11.23)
# total # of species: 1, # of stagnant species: 0
# [0]
# mutate: 0.038, simulate: 0.371
# --------------------------------
# new best genome exists
# 219 vs 207
# (max, avg) unadjusted fitness of generation 9 = (219, 11.408)
# total # of species: 1, # of stagnant species: 0
# [0]
# mutate: 0.039, simulate: 0.383
# --------------------------------
# (max, avg) unadjusted fitness of generation 10 = (105, 11.126)
# total # of species: 1, # of stagnant species: 0
# [0]
# mutate: 0.039, simulate: 0.397
# --------------------------------
