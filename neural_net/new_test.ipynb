# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..')))
from neural_net import nn
from sim.Sandbox import Sandbox
from sim.Simulation_Multiprocessing import Simulation
# Out:
# luts loaded successfully.

# %%
genome = Simulation.create_dense_network()
genome.enabled_synapses
# Out:
# [[SynapseGene 0] Neuron 0 -> Neuron 16, Weight: -0.6779324824875153, Enabled,
#  [SynapseGene 1] Neuron 1 -> Neuron 16, Weight: 0.957036846506415, Enabled,
#  [SynapseGene 2] Neuron 2 -> Neuron 16, Weight: 0.7096788726029502, Enabled,
#  [SynapseGene 3] Neuron 3 -> Neuron 16, Weight: 0.8368314757256856, Enabled,
#  [SynapseGene 4] Neuron 4 -> Neuron 16, Weight: -0.34354499597815535, Enabled,
#  [SynapseGene 5] Neuron 5 -> Neuron 16, Weight: -0.5524049735041792, Enabled,
#  [SynapseGene 6] Neuron 6 -> Neuron 16, Weight: 0.6613749621872198, Enabled,
#  [SynapseGene 7] Neuron 7 -> Neuron 16, Weight: -0.8179972269966791, Enabled,
#  [SynapseGene 8] Neuron 8 -> Neuron 16, Weight: 0.05667030972193321, Enabled,
#  [SynapseGene 9] Neuron 9 -> Neuron 16, Weight: 0.8413865168767927, Enabled,
#  [SynapseGene 10] Neuron 10 -> Neuron 16, Weight: 0.39037694662880584, Enabled,
#  [SynapseGene 11] Neuron 11 -> Neuron 16, Weight: -0.6629547174145438, Enabled,
# ...

# %%
genome.mutate()
# Out:
# [synapse weight change mutation] @ sg 0 (-0.82 -> -0.41)
# [synapse weight change mutation] @ sg 1 (0.40 -> 0.38)
# [synapse weight change mutation] @ sg 2 (-0.57 -> -0.58)
# [synapse weight change mutation] @ sg 4 (-0.23 -> -0.27)
# [synapse weight change mutation] @ sg 5 (-0.42 -> -1.15)
# [synapse weight change mutation] @ sg 6 (-2.31 -> -1.84)
# [synapse weight change mutation] @ sg 8 (0.03 -> 1.10)
# [synapse weight change mutation] @ sg 9 (2.85 -> 2.32)
# [synapse weight change mutation] @ sg 12 (2.42 -> 1.33)
# [synapse weight change mutation] @ sg 13 (-0.59 -> -0.34)
# [synapse weight change mutation] @ sg 14 (1.78 -> 2.19)
# [synapse weight change mutation] @ sg 16 (0.01 -> -0.37)
# [synapse weight change mutation] @ sg 17 (-2.52 -> -2.15)
# [synapse weight change mutation] @ sg 19 (-2.00 -> -1.20)
# [synapse weight change mutation] @ sg 20 (0.29 -> 0.90)
# [synapse weight change mutation] @ sg 21 (3.30 -> 2.35)
# [synapse weight change mutation] @ sg 24 (0.54 -> 0.31)
# ...

# %%
genome.enabled_synapses
# Out:
# [[SynapseGene 0] Neuron 0 -> Neuron 16, Weight: -0.41145450132472833, Enabled,
#  [SynapseGene 1] Neuron 1 -> Neuron 16, Weight: 0.37660928201498284, Enabled,
#  [SynapseGene 2] Neuron 2 -> Neuron 16, Weight: -0.5821383470251338, Enabled,
#  [SynapseGene 4] Neuron 4 -> Neuron 16, Weight: -0.2749540706463345, Enabled,
#  [SynapseGene 5] Neuron 5 -> Neuron 16, Weight: -1.1509404517136286, Enabled,
#  [SynapseGene 6] Neuron 6 -> Neuron 16, Weight: -1.8422517977582906, Enabled,
#  [SynapseGene 7] Neuron 7 -> Neuron 16, Weight: -2.9776049671229377, Enabled,
#  [SynapseGene 8] Neuron 8 -> Neuron 16, Weight: 1.095861833555186, Enabled,
#  [SynapseGene 9] Neuron 9 -> Neuron 16, Weight: 2.321466265168951, Enabled,
#  [SynapseGene 10] Neuron 10 -> Neuron 16, Weight: -1.1163121553504836, Enabled,
#  [SynapseGene 11] Neuron 11 -> Neuron 16, Weight: 0.2528472097344787, Enabled,
#  [SynapseGene 12] Neuron 12 -> Neuron 16, Weight: 1.3316715965172359, Enabled,
# ...
